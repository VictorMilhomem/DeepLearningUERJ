# %% [markdown]
# # **Final Assignment - Semantic Segmentation**
#
# Objective: Implement and evaluate two CNNs for Semantic Segmentation
#
# Dataset: ISPRS 2D Semantic Labeling Challenge (Vaihingen)
#
# <figure>
# <center>
# <img src= 'https://drive.google.com/uc?export=view&id=19wmyEXtnTV8gMOn02FPeJ8JcVSKVOycH'/>
# </figure>
#
# In the code below the network was trained only with image Train1.
#
# In the assignment you should use both Train1 and Train2 images to train.
#
# Notice that you will have to adapt the so that the network will take as imput an image concatenated with its DSM.

# %% [markdown]
# # **1. Import libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
from osgeo import ogr, gdal

from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Activation, Dense, Flatten, Dropout, concatenate, Conv2D, MaxPool2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **2. Defining root folder**

# %%
# root_path will be used to store trained models

from google.colab import drive
# mount your Google Drive
drive.mount('/content/drive', force_remount=True)

# adjust the path to the location where the models will be written / read
root_path = '/content/drive/My Drive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **3. Loading the data**

# %%
# Downloading the dataset and unpacking it.
# 6 files: Test_Image.tif, Test_DSM.tif, Test_Reference.tif, Train1_Image.tif, Train1_DSM.tif, Train1_Reference.tif, Train2_Image.tif, Train2_DSM.tif, Train2_Reference.tif

# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# !wget https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# !unrar e Images_Semantic_Segmentatio_Assignment.part1.rar
# Out:
# --2023-07-17 12:59:11--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part1.rar [following]
# --2023-07-17 12:59:12--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part1.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25165824 (24M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part1.rar’
#
# Images_Semantic_Seg 100%[===================>]  24.00M  --.-KB/s    in 0.08s
#
# 2023-07-17 12:59:13 (293 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part1.rar’ saved [25165824/25165824]
#
# --2023-07-17 12:59:13--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part2.rar [following]
# --2023-07-17 12:59:14--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part2.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25165824 (24M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part2.rar’
#
# Images_Semantic_Seg 100%[===================>]  24.00M  --.-KB/s    in 0.07s
#
# 2023-07-17 12:59:16 (351 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part2.rar’ saved [25165824/25165824]
#
# --2023-07-17 12:59:16--  https://github.com/gilson-costa/files/raw/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part3.rar [following]
# --2023-07-17 12:59:16--  https://raw.githubusercontent.com/gilson-costa/files/main/Images_Semantic_Segmentatio_Assignment.part3.rar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9414015 (9.0M) [application/octet-stream]
# Saving to: ‘Images_Semantic_Segmentatio_Assignment.part3.rar’
#
# Images_Semantic_Seg 100%[===================>]   8.98M  --.-KB/s    in 0.03s
#
# 2023-07-17 12:59:17 (305 MB/s) - ‘Images_Semantic_Segmentatio_Assignment.part3.rar’ saved [9414015/9414015]
#
#
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part1.rar
#
#   OK
#  42%
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part2.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#  84%
#
# Extracting from Images_Semantic_Segmentatio_Assignment.part3.rar
#
#   OK
#   OK
#   OK
# All OK

# %%
# Listing the contents of the virtual machine.
# !ls -l
# Out:
# total 226224
# drwx------ 6 root root     4096 Jul 17 12:59 drive
# -rw-r--r-- 1 root root 25165824 Jul 17 12:59 Images_Semantic_Segmentatio_Assignment.part1.rar
# -rw-r--r-- 1 root root 25165824 Jul 17 12:59 Images_Semantic_Segmentatio_Assignment.part2.rar
# -rw-r--r-- 1 root root  9414015 Jul 17 12:59 Images_Semantic_Segmentatio_Assignment.part3.rar
# drwxr-xr-x 1 root root     4096 Jul 13 13:33 sample_data
# -rw-r--r-- 1 root root 28852100 Aug 19  2014 Test_DSM.tif
# -rw-r--r-- 1 root root 21789756 Nov  1  2013 Test_Image.tif
# -rw-r--r-- 1 root root 22326104 Apr 28  2014 Test_Reference.tif
# -rw-r--r-- 1 root root 19707152 Aug 19  2014 Train1_DSM.tif
# -rw-r--r-- 1 root root 14870332 Nov  1  2013 Train1_Image.tif
# -rw-r--r-- 1 root root 15259952 Apr 28  2014 Train1_Reference.tif
# -rw-r--r-- 1 root root 19398356 Aug 19  2014 Train2_DSM.tif
# -rw-r--r-- 1 root root 14643100 Nov  1  2013 Train2_Image.tif
# -rw-r--r-- 1 root root 15036852 Apr 28  2014 Train2_Reference.tif

# %%
# Functions

def load_tiff_image(image):
  print (image)
  gdal_header = gdal.Open(image)
  img_gdal = gdal_header.ReadAsArray()
  img = np.transpose(img_gdal, (1,2,0))
  return img

def normalization(image):
  image_reshaped = image.reshape((image.shape[0]*image.shape[1]),image.shape[2])
  scaler = MinMaxScaler(feature_range=(0,1))
  scaler = scaler.fit(image_reshaped)
  image_normalized_ = scaler.fit_transform(image_reshaped)
  image_normalized = image_normalized_.reshape(image.shape[0],image.shape[1],image.shape[2])
  return image_normalized

# %%
# Loading and normalizing images

reference_train = load_tiff_image('Train1_Reference.tif')
print(reference_train.shape)
image_train = load_tiff_image('Train1_Image.tif')
# Normalizes training image (pixel values from 0 to 1)
image_train = normalization(image_train)
print(image_train.shape)

reference_test = load_tiff_image('Test_Reference.tif')
print(reference_test.shape)
image_test = load_tiff_image('Test_Image.tif')
# Normalizes testing image (pixel values from 0 to 1)
image_test = normalization(image_test)
print(image_test.shape)
# Out:
# Train1_Reference.tif
# (2565, 1919, 3)
# Train1_Image.tif
# (2565, 1919, 3)
# Test_Reference.tif
# (2558, 2818, 3)
# Test_Image.tif
# (2558, 2818, 3)

# %% [markdown]
# # **4. Creating labeled images from references**

# %%
# Defining number of classes and class indices in relation to reference images (RGB)

num_classes = 6
color2label = {
    (255, 255, 255) : 0,  # Impervious surfaces
    (0,   255, 255) : 1,  # Low vegetation
    (0,     0, 255) : 2,  # Building
    (0,   255,   0) : 3,  # Tree
    (255, 255,   0) : 4   # Car
}

def create_label_image(rgb_image):
  W = np.power(256, [[0],[1],[2]])
  img_index = rgb_image.dot(W).squeeze(-1)
  values = np.unique(img_index)
  label_image = np.zeros(img_index.shape)
  for i, c in enumerate(values):
    try:
      label_image[img_index==c] = color2label[tuple(rgb_image[img_index==c][0])]
    except:
      pass
  return label_image

# %%
# Tranforming regerence RGB images into label images

labels_train = create_label_image(reference_train)
print(labels_train.shape)
labels_test = create_label_image(reference_test)
print(labels_test.shape)
# Out:
# (2565, 1919)
# (2558, 2818)

# %%
# Inspecting label images (train and test)

print('\nPlotting images...')

fig1, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))
ax1.imshow( reference_train )
ax1.set_title('Reference RGB (train)', fontsize=20)
ax1.axis('off')
ax2.imshow( labels_train, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference Labels (train)', fontsize=20)
ax2.axis('off')

fig2, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))
ax1.imshow( reference_test )
ax1.set_title('Reference RGB (test)', fontsize=20)
ax1.axis('off')
ax2.imshow( labels_test, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference Labels (test)', fontsize=20)
ax2.axis('off')
# Out:
# Plotting images...
# (-0.5, 2817.5, 2557.5, -0.5)

# %% [markdown]
# # **5. Extracting image patches for training**

# %%
# Constants and functions

# patch_size defines the measures (spatial dimensions) of the patch.
# Working with square patches (H = W). Therefore, a scalar variable is enough.
patch_size = 256

# patch_stride determine the position of the next patch.
# A patch_stride smaller than the spatial dimension of the patch determines an overlapping.
# 25% ​​overlap between patches.
patch_stride = patch_size - (patch_size // 4)

# channels of the image/patches to be segmented
image_channels = 3

# shape of the input to the network (training)
input_shape = (patch_size, patch_size, image_channels)

# Function: extract_patches
# -------------------------
# Extract patches from the original and reference image
#
# Input parameters:
#   image      = array containing the original image (h,w,c)
#   reference  = array containing the reference image (h,w,c)
#   patch_size = patch size (scalar). The shape of the patch is square.
#   stride     = displacement to be applied.
#   border_patches = include patches overlaping image borders
#
# Returns:
#   A, B = List containing the patches for the input image (A) and respective reference (B).
#
def extract_patches(image, reference, patch_size, stride, border_patches=False):
    print("Image dimensions:", image.shape)
    print("Reference dimensions:", reference.shape)

    patch_img = []
    patch_ref = []

    h = image.shape[0] // stride
    w = image.shape[1] // stride

    for m in range(0, h):
        for n in range(0, w):
            #print('M %d, N %d, start %d finish %d , start %d finish %d' % (m, n, m*stride , m*stride+patch_size, n*stride, n*stride+patch_size) )
            if ( (m*stride+patch_size <= image.shape[0]) and (n*stride+patch_size <= image.shape[1]) ):
                patch_img.append( image[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size,:] )
                patch_ref.append( reference[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size] )
            elif border_patches:
                border_patch_img = np.zeros((patch_size,patch_size,image_channels))
                border_patch_ref = np.zeros((patch_size,patch_size))
                if (m*stride+patch_size > image.shape[0]):
                  border_mmax = patch_size-(m*stride+patch_size-image.shape[0])
                else:
                  border_mmax = patch_size-1
                if (n*stride+patch_size > image.shape[1]):
                  border_nmax = patch_size-(n*stride+patch_size-image.shape[1])
                else:
                  border_nmax = patch_size-1

                border_patch_img[0:border_mmax,0:border_nmax,:] = image[m*stride:m*stride+border_mmax,n*stride:n*stride+border_nmax,:]
                border_patch_ref[0:border_mmax,0:border_nmax] = reference[m*stride:m*stride+border_mmax,n*stride:n*stride+border_nmax]
                patch_img.append( border_patch_img )
                patch_ref.append( border_patch_ref )

    return np.array(patch_img), np.array(patch_ref)

# %%
# Extracting training patches

x_patches, y_patches = extract_patches(image_train, labels_train, patch_size, patch_stride)

# Transform y_patches, shape (N, H, W) into shape (N, H, W, C). Necessary for data agumentation.
y_patches = np.expand_dims(y_patches, 3)

print( "Number of patches: %d %s " % ( x_patches.shape[0], x_patches.shape[1:] ) )
print( "Number of labeled references: %d %s " % ( y_patches.shape[0], y_patches.shape[1:] ) )
# Out:
# Image dimensions: (2565, 1919, 3)
# Reference dimensions: (2565, 1919)
# Number of patches: 117 (256, 256, 3)
# Number of labeled references: 117 (256, 256, 1)

# %%
# Inspecting an arbitrary image patch

image_index = 20

print('\nPlotting images...')
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 10))

ax1.imshow( x_patches[image_index] )
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_patches[image_index, :, :, 0], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Labeled reference', fontsize=20)
ax2.axis('off')
# Out:
# Plotting images...
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# # **6. Separating training and validation patches**

# %%
# Defining the percentage of the training set to be used as validation
valid_percent = 0.2

# Calculating the boundary (index) between training set and validation.
# The premise is always that X and Y have the same number of elements.
limit = len(x_patches) - int( len(x_patches)*valid_percent )

# Building a list of indexes from 0 to N, where N corresponds to the number of images (patches).
indexes = [i for i in range(x_patches.shape[0])]

# Generating randomness in the list
import random
random.shuffle(indexes)

# Indexes of the images that will be used for training
indexes_for_train = indexes[:limit]
# ndexes of the images that will be used for validation
indexes_for_valid = indexes[limit:]

# Training set
x_train = x_patches[indexes_for_train]
y_train = y_patches[indexes_for_train]

# Validation set
x_valid = x_patches[indexes_for_valid]
y_valid = y_patches[indexes_for_valid]

print( "Número de imagens no conjunto de treinamento: %d " % ( len(x_train) ) )
print( "Número de imagens no conjunto de validação: %d " % ( len(x_valid) ) )

# Freeing up memory
x_patches = 0
y_patches = 0
# Out:
# Número de imagens no conjunto de treinamento: 94
# Número de imagens no conjunto de validação: 23

# %% [markdown]
# # **7. Data augmentation**

# %%
# Setting data augmentation tranformations and creating data generators

# Only rotations by 90 degrees
def orthogonal_rot(image):
    return np.rot90(image, np.random.choice([-1, 0, 1]))

# Tranformations for image patches
datagen_args_x = dict(
        rotation_range=90, # rotation
        width_shift_range=0.15, # horizontal shift
        height_shift_range=0.15, # vertical shift
        zoom_range=0.25, # zoom
        preprocessing_function=orthogonal_rot,
        horizontal_flip=True, # horizontal flip
        vertical_flip=True, # vertical flip
        #brightness_range=[0.8,1.2], # brightness
        fill_mode='constant',
        cval=0
)

# Transformations for reference patches
datagen_args_y = dict(
        rotation_range=90, # rotation
        width_shift_range=0.15, # horizontal shift
        height_shift_range=0.15, # vertical shift
        zoom_range=0.25, # zoom
        preprocessing_function=orthogonal_rot,
        horizontal_flip=True, # horizontal flip
        vertical_flip=True, # vertical flip
        fill_mode='constant',
        cval=0
)

# Its necessary to provide the same seed and kwargs to the flow method (images and references)
seed = 1
x_datagen = ImageDataGenerator(**datagen_args_x)
y_datagen = ImageDataGenerator(**datagen_args_y)

# %%
# Example of Data Augmentation for an arbitrary patch

show_index = 25

x_patch = np.expand_dims( x_train[show_index], 0 )
y_patch = np.expand_dims( y_train[show_index], 0 )

x_iterator = x_datagen.flow(x_patch, seed=seed)
y_iterator = y_datagen.flow(y_patch, seed=seed)

data_iterator = next( zip( x_iterator, y_iterator ) )

nrows = 2
ncols = 5
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(25,12))

# generating transformed images
for j in range(ncols):
    data_iterator = next( zip( x_iterator, y_iterator ) )
    ax[0][j].axis('off')
    ax[0][j].imshow(next(x_iterator)[0])
    ax[1][j].axis('off')
    ax[1][j].imshow(data_iterator[1][0,:,:,0], cmap='gray', vmin=0, vmax=num_classes )

# %% [markdown]
# # **8. Building the CNN model**

# %%
# Defining the structure of the CNN

def conv_block(input, neurons, quantity, activation="relu", pooling=(2,2), drop=0.5):
  _conv = Conv2D(neurons * quantity, (3,3), activation=activation, padding="same")(input)
  _conv =  Conv2D(neurons * quantity, (3,3), activation=activation, padding="same")(_conv)
  _pool = MaxPool2D(pooling)(_conv)
  _pool = Dropout(drop)(_pool)
  return _pool, _conv


def deconv_block(input, conv, neurons, quantity, activation="relu", pooling=(2,2), drop=0.5):
  _deconv = Conv2DTranspose(neurons * quantity, (3, 3), strides=(2, 2), padding="same")(input)
  _uconv = concatenate([_deconv, conv])
  _uconv = Dropout(0.5)(_uconv)
  _uconv = Conv2D(neurons * quantity, (3, 3), activation="relu", padding="same")(_uconv)
  _uconv = Conv2D(neurons * quantity, (3, 3), activation="relu", padding="same")(_uconv)
  return _uconv

def unet(input_shape, n_classes):
# U-Net architecture
  neurons = 64
  input_img = Input(input_shape)
  #input_img = data_augmentation(input_img)
  block1, conv1 = conv_block(input_img, neurons, 1, drop=0.25)
  block2, conv2 = conv_block(block1, neurons, quantity=2)
  block3, conv3 = conv_block(block2, neurons, quantity=4)
  block4, conv4 = conv_block(block3, neurons, quantity=8)
  # middle
  convm = Conv2D(neurons * 16, (3,3), activation="relu", padding="same")(block4)
  convm = Conv2D(neurons * 16, (3,3), activation="relu", padding="same")(convm)
  # convT
  deconv1 = deconv_block(convm, conv4, neurons, quantity=8)
  deconv2 = deconv_block(deconv1, conv3, neurons, quantity=4)
  deconv3 = deconv_block(deconv2, conv2, neurons,quantity=2)
  deconv4 = deconv_block(deconv3, conv1, neurons, quantity=1, drop=0.25)

  output = Conv2D(n_classes,(1,1), activation = 'softmax')(deconv4)
  return Model(inputs = input_img, outputs = output, name='U-Net')

# %%
# Building the model

model = unet(input_shape, num_classes)
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  1792        ['input_2[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_20[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 128, 128, 64  0           ['max_pooling2d_4[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  73856       ['dropout_8[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_21[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_22[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64, 128)  0           ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  295168      ['dropout_9[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_24[0][0]']
#
#  dropout_10 (Dropout)           (None, 32, 32, 256)  0           ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 512)  1180160     ['dropout_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv2d_26[0][0]']
#
#  dropout_11 (Dropout)           (None, 16, 16, 512)  0           ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 1024  4719616     ['dropout_11[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 1024  9438208     ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 512)  4719104    ['conv2d_28[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  dropout_12 (Dropout)           (None, 32, 32, 1024  0           ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 512)  4719104     ['dropout_12[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 256)  1179904    ['conv2d_30[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  dropout_13 (Dropout)           (None, 64, 64, 512)  0           ['concatenate_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 256)  1179904     ['dropout_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 12  295040     ['conv2d_32[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  dropout_14 (Dropout)           (None, 128, 128, 25  0           ['concatenate_6[0][0]']
#                                 6)
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 12  295040      ['dropout_14[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 64  73792      ['conv2d_34[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'conv2d_20[0][0]']
#
#  dropout_15 (Dropout)           (None, 256, 256, 12  0           ['concatenate_7[0][0]']
#                                 8)
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 64  73792       ['dropout_15[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 6)  390         ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 34,513,670
# Trainable params: 34,513,670
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # **9. Functions for training the network**

# %%
# Functions for training

def set_number_of_batches(qt_train_samples, qt_valid_samples, batch_size, data_augmentation, number_samples_for_generator=6):
    if data_augmentation:
        train_batchs_qtd = qt_train_samples//number_samples_for_generator
        valid_batchs_qtd = qt_valid_samples//number_samples_for_generator
    else:
        train_batchs_qtd = qt_train_samples//batch_size
        valid_batchs_qtd = qt_valid_samples//batch_size

    return train_batchs_qtd, valid_batchs_qtd

def get_batch_samples(x, y, batch, batch_size, data_augmentation, number_samples_for_generator):
    if data_augmentation:
        x_batch = x[batch * number_samples_for_generator : (batch + 1) * number_samples_for_generator, : , : , :]
        y_batch = y[batch * number_samples_for_generator : (batch + 1) * number_samples_for_generator, : , : , :]

        x_iterator = x_datagen.flow(x_batch, seed=batch)
        y_iterator = y_datagen.flow(y_batch, seed=batch)

        x_batch = np.array([next(x_iterator)[0] for _ in range(batch_size)])
        y_batch = np.array([next(y_iterator)[0] for _ in range(batch_size)])
    else:
        x_batch = x[batch * batch_size : (batch + 1) * batch_size, : , : , :]
        y_batch = y[batch * batch_size : (batch + 1) * batch_size, : , : , :]

    return x_batch, y_batch

def train_unet(net, x_train, y_train, x_valid, y_valid, batch_size, epochs, early_stopping_epochs, early_stopping_delta, filepath, filename, data_augmentation=False, number_samples_for_generator=1):
    print('Start the training...')

    # calculating number of batches
    train_batchs_qtd, valid_batchs_qtd = set_number_of_batches(x_train.shape[0], x_valid.shape[0], batch_size, data_augmentation, number_samples_for_generator)

    history_train = []
    history_valid = []
    valid_loss_best_model = float('inf')
    no_improvement_count = 0

    for epoch in range(epochs):
        print('Start epoch ... %d ' %(epoch) )
        # shuffle train set
        x_train, y_train = shuffle(x_train , y_train, random_state = 0)

        # TRAINING
        train_loss = np.zeros((1 , 2))
        # mini batches strategy
        for  batch in range(train_batchs_qtd):
            print('Start batch ... %d ' %(batch) )
            x_train_batch, y_train_batch = get_batch_samples(x_train, y_train, batch, batch_size, data_augmentation, number_samples_for_generator)
            train_loss = train_loss + net.train_on_batch(x_train_batch, y_train_batch)

        # Estimating the loss in the training set
        train_loss = train_loss/train_batchs_qtd

        # VALIDATING
        valid_loss = np.zeros((1 , 2))
        # Evaluating the network (model) with the validation set
        for  batch in range(valid_batchs_qtd):
            x_valid_batch, y_valid_batch = get_batch_samples(x_valid, y_valid, batch, batch_size, data_augmentation, number_samples_for_generator)
            valid_loss = valid_loss + net.test_on_batch(x_valid_batch, y_valid_batch)

        # Estimating the loss in the validation set
        valid_loss = valid_loss/valid_batchs_qtd

        # Showing the results.
        print("Epoch: %d [training loss: %f , Train acc.: %.2f%%][Test loss: %f , Test acc.:%.2f%%]" %(epoch , train_loss[0 , 0], 100*train_loss[0 , 1] , valid_loss[0 , 0] , 100 * valid_loss[0 , 1]))
        history_train.append( train_loss )
        history_valid.append( valid_loss )

        # Early Stopping
        if (1-(valid_loss[0 , 0]/valid_loss_best_model)) < early_stopping_delta:
            if no_improvement_count+1 >= early_stopping_epochs:
                print('Early Stopping reached')
                break
            else:
                no_improvement_count = no_improvement_count+1
        else:
            valid_loss_best_model = valid_loss[0 , 0]
            no_improvement_count = 0

            # Saving best model
            print("Saving the model...")
            net.save(filepath+filename+'.h5')

    return [ history_train, history_valid ]

# %%
# Converter os rótulos para inteiros
# Convert labels to integers
labels_train = y_train.astype(int).flatten()
labels_test = y_valid.astype(int).flatten()

# Get unique classes present in the labels
classes = np.unique(np.concatenate((labels_train, labels_test)))

train_class_counts = np.bincount(labels_train)
test_class_counts = np.bincount(labels_test)

class_labels = ['Impervious surfaces', 'Low vegetation', 'Building', 'Tree', 'Car']

train_class_counts = np.bincount(labels_train)
test_class_counts = np.bincount(labels_test)


# Criar o gráfico de barras da distribuição das classes
fig, ax = plt.subplots()
ax.bar(class_labels, train_class_counts, label='Treinamento')
ax.bar(class_labels, test_class_counts, label='Validação', alpha=0.5)
ax.set_xlabel('Classes')
ax.set_ylabel('Contagem')
ax.set_title('Distribuição das Classes')
ax.legend()
ax.set_xticklabels(class_labels, rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-23-ae2f4f28cc33>:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(class_labels, rotation=45, ha='right')

# %% [markdown]
# # **10. Defining hyperparameters**

# %%
# Defining hyperparameters for training

batch_size = 16
epochs = 200

# Fixed class weights: [Impervious surfaces, Low vegetation, Building, Tree, Car]
class_weights = [0.25, 0.2, 0.55, 0.10, 4.0]

# Early stoping parameters
early_stopping_epochs = 20
early_stopping_delta = 0.0001 # delta improvement equivalent to 0.01%

data_augmentation = True
number_samples_for_generator = 8

# optimizer
adam = Adam(learning_rate = 0.0001 , beta_1=0.9, amsgrad=False, epsilon=1e-7)

# %% [markdown]
# # **11. Start training**

# %%
# Compile the model
model.compile(loss = "sparse_categorical_crossentropy", optimizer=adam , metrics=['accuracy'], loss_weights=class_weights)

# Train the model
best_model_filename = 'best_CNN_model'
#history = train_unet(model, x_train, y_train, x_valid, y_valid, batch_size, epochs, early_stopping_epochs, early_stopping_delta, root_path, best_model_filename, data_augmentation, number_samples_for_generator)
# Uncomment the line above for training with the whole dataset!!!
history = train_unet(model, x_train[0:64], y_train[0:64], x_valid[0:16], y_valid[0:16], batch_size, epochs, early_stopping_epochs, early_stopping_delta, root_path, best_model_filename, data_augmentation, number_samples_for_generator)
# Out:
# Start the training...
# Start epoch ... 0
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 0 [training loss: 0.438923 , Train acc.: 31.05%][Test loss: 0.431187 , Test acc.:40.30%]
# Saving the model...
# Start epoch ... 1
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 1 [training loss: 0.409744 , Train acc.: 34.98%][Test loss: 0.386169 , Test acc.:42.14%]
# Saving the model...
# Start epoch ... 2
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 2 [training loss: 0.379517 , Train acc.: 38.91%][Test loss: 0.383627 , Test acc.:32.22%]
# Saving the model...
# Start epoch ... 3
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 3 [training loss: 0.374158 , Train acc.: 37.41%][Test loss: 0.365918 , Test acc.:44.49%]
# Saving the model...
# Start epoch ... 4
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 4 [training loss: 0.358777 , Train acc.: 35.87%][Test loss: 0.353814 , Test acc.:41.25%]
# Saving the model...
# Start epoch ... 5
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 5 [training loss: 0.355409 , Train acc.: 38.15%][Test loss: 0.354323 , Test acc.:51.68%]
# Start epoch ... 6
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 6 [training loss: 0.341481 , Train acc.: 44.93%][Test loss: 0.340120 , Test acc.:33.90%]
# Saving the model...
# Start epoch ... 7
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 7 [training loss: 0.335558 , Train acc.: 40.00%][Test loss: 0.327925 , Test acc.:50.37%]
# Saving the model...
# Start epoch ... 8
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 8 [training loss: 0.304344 , Train acc.: 44.88%][Test loss: 0.301247 , Test acc.:52.47%]
# Saving the model...
# Start epoch ... 9
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 9 [training loss: 0.294251 , Train acc.: 48.94%][Test loss: 0.302286 , Test acc.:49.46%]
# Start epoch ... 10
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 10 [training loss: 0.285744 , Train acc.: 57.10%][Test loss: 0.281749 , Test acc.:55.12%]
# Saving the model...
# Start epoch ... 11
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 11 [training loss: 0.285304 , Train acc.: 50.90%][Test loss: 0.288325 , Test acc.:50.08%]
# Start epoch ... 12
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 12 [training loss: 0.270815 , Train acc.: 56.30%][Test loss: 0.266805 , Test acc.:52.19%]
# Saving the model...
# Start epoch ... 13
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 13 [training loss: 0.263213 , Train acc.: 55.30%][Test loss: 0.261739 , Test acc.:54.63%]
# Saving the model...
# Start epoch ... 14
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 14 [training loss: 0.247088 , Train acc.: 60.34%][Test loss: 0.248455 , Test acc.:56.05%]
# Saving the model...
# Start epoch ... 15
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 15 [training loss: 0.250827 , Train acc.: 54.95%][Test loss: 0.246943 , Test acc.:58.18%]
# Saving the model...
# Start epoch ... 16
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 16 [training loss: 0.241283 , Train acc.: 58.61%][Test loss: 0.232554 , Test acc.:56.62%]
# Saving the model...
# Start epoch ... 17
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 17 [training loss: 0.232029 , Train acc.: 58.98%][Test loss: 0.222416 , Test acc.:59.98%]
# Saving the model...
# Start epoch ... 18
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 18 [training loss: 0.216597 , Train acc.: 63.16%][Test loss: 0.218955 , Test acc.:57.33%]
# Saving the model...
# Start epoch ... 19
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 19 [training loss: 0.210298 , Train acc.: 63.33%][Test loss: 0.210821 , Test acc.:61.41%]
# Saving the model...
# Start epoch ... 20
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 20 [training loss: 0.214972 , Train acc.: 60.98%][Test loss: 0.207633 , Test acc.:64.73%]
# Saving the model...
# Start epoch ... 21
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 21 [training loss: 0.207797 , Train acc.: 63.62%][Test loss: 0.210529 , Test acc.:63.20%]
# Start epoch ... 22
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 22 [training loss: 0.218008 , Train acc.: 61.39%][Test loss: 0.203157 , Test acc.:65.61%]
# Saving the model...
# Start epoch ... 23
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 23 [training loss: 0.204004 , Train acc.: 64.09%][Test loss: 0.207976 , Test acc.:60.34%]
# Start epoch ... 24
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 24 [training loss: 0.203074 , Train acc.: 64.41%][Test loss: 0.200296 , Test acc.:65.95%]
# Saving the model...
# Start epoch ... 25
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 25 [training loss: 0.211360 , Train acc.: 60.75%][Test loss: 0.208987 , Test acc.:60.75%]
# Start epoch ... 26
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 26 [training loss: 0.204641 , Train acc.: 65.91%][Test loss: 0.196617 , Test acc.:63.42%]
# Saving the model...
# Start epoch ... 27
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 27 [training loss: 0.202998 , Train acc.: 63.43%][Test loss: 0.199104 , Test acc.:64.86%]
# Start epoch ... 28
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 28 [training loss: 0.201749 , Train acc.: 66.67%][Test loss: 0.195832 , Test acc.:68.53%]
# Saving the model...
# Start epoch ... 29
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 29 [training loss: 0.187923 , Train acc.: 69.07%][Test loss: 0.196302 , Test acc.:65.01%]
# Start epoch ... 30
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 30 [training loss: 0.199850 , Train acc.: 66.23%][Test loss: 0.190337 , Test acc.:69.43%]
# Saving the model...
# Start epoch ... 31
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 31 [training loss: 0.194587 , Train acc.: 69.20%][Test loss: 0.188471 , Test acc.:67.44%]
# Saving the model...
# Start epoch ... 32
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 32 [training loss: 0.193116 , Train acc.: 66.95%][Test loss: 0.191871 , Test acc.:69.17%]
# Start epoch ... 33
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 33 [training loss: 0.194030 , Train acc.: 68.97%][Test loss: 0.185038 , Test acc.:69.99%]
# Saving the model...
# Start epoch ... 34
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 34 [training loss: 0.189672 , Train acc.: 67.24%][Test loss: 0.188669 , Test acc.:68.27%]
# Start epoch ... 35
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 35 [training loss: 0.191295 , Train acc.: 68.84%][Test loss: 0.182672 , Test acc.:68.98%]
# Saving the model...
# Start epoch ... 36
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 36 [training loss: 0.196348 , Train acc.: 64.35%][Test loss: 0.189714 , Test acc.:69.15%]
# Start epoch ... 37
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 37 [training loss: 0.193007 , Train acc.: 66.26%][Test loss: 0.185491 , Test acc.:68.17%]
# Start epoch ... 38
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 38 [training loss: 0.189381 , Train acc.: 67.33%][Test loss: 0.197388 , Test acc.:65.19%]
# Start epoch ... 39
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 39 [training loss: 0.189283 , Train acc.: 68.75%][Test loss: 0.178853 , Test acc.:71.32%]
# Saving the model...
# Start epoch ... 40
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 40 [training loss: 0.183819 , Train acc.: 68.92%][Test loss: 0.179775 , Test acc.:70.00%]
# Start epoch ... 41
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 41 [training loss: 0.190626 , Train acc.: 68.13%][Test loss: 0.187470 , Test acc.:69.65%]
# Start epoch ... 42
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 42 [training loss: 0.181840 , Train acc.: 69.97%][Test loss: 0.177534 , Test acc.:70.51%]
# Saving the model...
# Start epoch ... 43
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 43 [training loss: 0.197026 , Train acc.: 65.31%][Test loss: 0.181710 , Test acc.:68.20%]
# Start epoch ... 44
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 44 [training loss: 0.193036 , Train acc.: 67.47%][Test loss: 0.190974 , Test acc.:67.02%]
# Start epoch ... 45
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 45 [training loss: 0.198742 , Train acc.: 64.51%][Test loss: 0.182316 , Test acc.:71.47%]
# Start epoch ... 46
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 46 [training loss: 0.187786 , Train acc.: 71.04%][Test loss: 0.187808 , Test acc.:67.84%]
# Start epoch ... 47
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 47 [training loss: 0.188347 , Train acc.: 67.92%][Test loss: 0.176984 , Test acc.:70.73%]
# Saving the model...
# Start epoch ... 48
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 48 [training loss: 0.181988 , Train acc.: 70.29%][Test loss: 0.180604 , Test acc.:70.24%]
# Start epoch ... 49
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 49 [training loss: 0.190206 , Train acc.: 65.05%][Test loss: 0.178480 , Test acc.:70.72%]
# Start epoch ... 50
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 50 [training loss: 0.186735 , Train acc.: 69.56%][Test loss: 0.177195 , Test acc.:71.09%]
# Start epoch ... 51
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 51 [training loss: 0.185269 , Train acc.: 69.56%][Test loss: 0.174450 , Test acc.:71.45%]
# Saving the model...
# Start epoch ... 52
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 52 [training loss: 0.173283 , Train acc.: 72.71%][Test loss: 0.169492 , Test acc.:73.13%]
# Saving the model...
# Start epoch ... 53
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 53 [training loss: 0.173526 , Train acc.: 70.74%][Test loss: 0.178096 , Test acc.:70.26%]
# Start epoch ... 54
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 54 [training loss: 0.176395 , Train acc.: 71.74%][Test loss: 0.172125 , Test acc.:71.76%]
# Start epoch ... 55
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 55 [training loss: 0.179123 , Train acc.: 68.65%][Test loss: 0.168659 , Test acc.:71.75%]
# Saving the model...
# Start epoch ... 56
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 56 [training loss: 0.179536 , Train acc.: 70.84%][Test loss: 0.168784 , Test acc.:71.96%]
# Start epoch ... 57
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 57 [training loss: 0.168831 , Train acc.: 71.06%][Test loss: 0.166969 , Test acc.:72.32%]
# Saving the model...
# Start epoch ... 58
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 58 [training loss: 0.175333 , Train acc.: 70.91%][Test loss: 0.165713 , Test acc.:73.18%]
# Saving the model...
# Start epoch ... 59
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 59 [training loss: 0.170976 , Train acc.: 71.58%][Test loss: 0.164494 , Test acc.:72.50%]
# Saving the model...
# Start epoch ... 60
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 60 [training loss: 0.171574 , Train acc.: 70.51%][Test loss: 0.175735 , Test acc.:66.42%]
# Start epoch ... 61
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 61 [training loss: 0.168618 , Train acc.: 71.83%][Test loss: 0.167010 , Test acc.:71.23%]
# Start epoch ... 62
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 62 [training loss: 0.184022 , Train acc.: 66.57%][Test loss: 0.176148 , Test acc.:67.52%]
# Start epoch ... 63
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 63 [training loss: 0.172904 , Train acc.: 70.39%][Test loss: 0.165139 , Test acc.:72.13%]
# Start epoch ... 64
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 64 [training loss: 0.168187 , Train acc.: 71.60%][Test loss: 0.167553 , Test acc.:70.34%]
# Start epoch ... 65
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 65 [training loss: 0.167697 , Train acc.: 71.93%][Test loss: 0.159727 , Test acc.:73.28%]
# Saving the model...
# Start epoch ... 66
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 66 [training loss: 0.167105 , Train acc.: 71.73%][Test loss: 0.165987 , Test acc.:72.81%]
# Start epoch ... 67
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 67 [training loss: 0.165384 , Train acc.: 72.52%][Test loss: 0.155464 , Test acc.:74.05%]
# Saving the model...
# Start epoch ... 68
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 68 [training loss: 0.164280 , Train acc.: 70.79%][Test loss: 0.157679 , Test acc.:72.73%]
# Start epoch ... 69
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 69 [training loss: 0.159666 , Train acc.: 73.50%][Test loss: 0.159835 , Test acc.:73.09%]
# Start epoch ... 70
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 70 [training loss: 0.166545 , Train acc.: 70.12%][Test loss: 0.158096 , Test acc.:72.66%]
# Start epoch ... 71
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 71 [training loss: 0.162812 , Train acc.: 71.86%][Test loss: 0.160048 , Test acc.:72.40%]
# Start epoch ... 72
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 72 [training loss: 0.169008 , Train acc.: 69.92%][Test loss: 0.169669 , Test acc.:70.57%]
# Start epoch ... 73
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 73 [training loss: 0.165596 , Train acc.: 72.39%][Test loss: 0.156351 , Test acc.:73.67%]
# Start epoch ... 74
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 74 [training loss: 0.159199 , Train acc.: 72.70%][Test loss: 0.163781 , Test acc.:71.98%]
# Start epoch ... 75
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 75 [training loss: 0.170083 , Train acc.: 70.80%][Test loss: 0.174288 , Test acc.:66.68%]
# Start epoch ... 76
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 76 [training loss: 0.160086 , Train acc.: 71.91%][Test loss: 0.156991 , Test acc.:72.94%]
# Start epoch ... 77
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 77 [training loss: 0.167731 , Train acc.: 70.80%][Test loss: 0.164460 , Test acc.:71.95%]
# Start epoch ... 78
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 78 [training loss: 0.159699 , Train acc.: 73.20%][Test loss: 0.158669 , Test acc.:71.93%]
# Start epoch ... 79
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 79 [training loss: 0.164563 , Train acc.: 71.64%][Test loss: 0.158797 , Test acc.:71.97%]
# Start epoch ... 80
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 80 [training loss: 0.152581 , Train acc.: 74.73%][Test loss: 0.151096 , Test acc.:74.87%]
# Saving the model...
# Start epoch ... 81
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 81 [training loss: 0.162620 , Train acc.: 71.77%][Test loss: 0.170172 , Test acc.:68.18%]
# Start epoch ... 82
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 82 [training loss: 0.154579 , Train acc.: 73.64%][Test loss: 0.148734 , Test acc.:75.60%]
# Saving the model...
# Start epoch ... 83
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 83 [training loss: 0.164918 , Train acc.: 70.01%][Test loss: 0.165283 , Test acc.:69.60%]
# Start epoch ... 84
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 84 [training loss: 0.156248 , Train acc.: 74.16%][Test loss: 0.149698 , Test acc.:75.90%]
# Start epoch ... 85
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 85 [training loss: 0.161637 , Train acc.: 71.92%][Test loss: 0.159954 , Test acc.:72.57%]
# Start epoch ... 86
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 86 [training loss: 0.156514 , Train acc.: 73.94%][Test loss: 0.148741 , Test acc.:75.31%]
# Start epoch ... 87
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 87 [training loss: 0.150560 , Train acc.: 74.64%][Test loss: 0.154213 , Test acc.:73.01%]
# Start epoch ... 88
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 88 [training loss: 0.156563 , Train acc.: 73.27%][Test loss: 0.150508 , Test acc.:74.66%]
# Start epoch ... 89
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 89 [training loss: 0.163741 , Train acc.: 71.25%][Test loss: 0.160633 , Test acc.:70.40%]
# Start epoch ... 90
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 90 [training loss: 0.164956 , Train acc.: 71.36%][Test loss: 0.164903 , Test acc.:69.41%]
# Start epoch ... 91
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 91 [training loss: 0.152539 , Train acc.: 73.77%][Test loss: 0.151846 , Test acc.:74.47%]
# Start epoch ... 92
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 92 [training loss: 0.157448 , Train acc.: 73.45%][Test loss: 0.157744 , Test acc.:72.44%]
# Start epoch ... 93
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 93 [training loss: 0.161570 , Train acc.: 71.24%][Test loss: 0.153195 , Test acc.:73.95%]
# Start epoch ... 94
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 94 [training loss: 0.154640 , Train acc.: 73.83%][Test loss: 0.156787 , Test acc.:72.60%]
# Start epoch ... 95
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 95 [training loss: 0.153098 , Train acc.: 74.50%][Test loss: 0.149292 , Test acc.:73.92%]
# Start epoch ... 96
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 96 [training loss: 0.152420 , Train acc.: 74.03%][Test loss: 0.153661 , Test acc.:74.54%]
# Start epoch ... 97
# Start batch ... 0
# Start batch ... 1
# Start batch ... 2
# Start batch ... 3
# Start batch ... 4
# Start batch ... 5
# Start batch ... 6
# Start batch ... 7
# Epoch: 97 [training loss: 0.152928 , Train acc.: 73.75%][Test loss: 0.155378 , Test acc.:72.49%]
# Start epoch ... 98
# Start batch ... 0
# Start batch ... 1

# %% [markdown]
# # **12. Training History Graph**

# %%
# Functions

def show_graph_loss_accuracy(history,accuracy_position):
    plt.rcParams['axes.facecolor']='white'
    plt.figure(num=1, figsize=(14,6))

    config = [ { 'title': 'model accuracy', 'ylabel': 'accuracy', 'legend_position': 'upper left', 'index_position': accuracy_position },
               { 'title': 'model loss', 'ylabel': 'loss', 'legend_position': 'upper right', 'index_position': 0 } ]

    for i in range(len(config)):

        plot_number = 120 + (i+1)
        plt.subplot(plot_number)
        plt.plot(history[0,:,0,config[i]['index_position']])
        plt.plot(history[1,:,0,config[i]['index_position']])
        plt.title(config[i]['title'])
        plt.ylabel(config[i]['ylabel'])
        plt.xlabel('epoch')
        plt.legend(['train', 'valid'], loc=config[i]['legend_position'])
        plt.tight_layout()

    plt.show()

# %%
# Show history

show_graph_loss_accuracy(np.asarray(history),1)

# %% [markdown]
# # **13. Evaluating the CNN model over training and validation data**

# %%
# Functions

def Test(model, patch_test):
    result = model.predict(patch_test)
    predicted_classes = np.argmax(result, axis=-1)
    return predicted_classes

def compute_metrics(true_labels, predicted_labels):
    accuracy = 100*accuracy_score(true_labels, predicted_labels)
    f1score = 100*f1_score(true_labels, predicted_labels, average=None)
    recall = 100*recall_score(true_labels, predicted_labels, average=None)
    precision = 100*precision_score(true_labels, predicted_labels, average=None)
    return accuracy, f1score, recall, precision

# %%
# load the best model (.h5 file)
model = load_model(root_path + best_model_filename + '.h5', compile=False)

# Test the model over training and validation data
pred_train = Test(model, x_train)
pred_valid = Test(model, x_valid)
# Out:
# 3/3 [==============================] - 32s 8s/step
# 1/1 [==============================] - 12s 12s/step

# %%
# Showing the prediction for an arbitrary training patch

index = 20

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow(x_train[index])
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_train[index, :, :, 0], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_train[index], cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')
# Out:
# Plotting images...
# (-0.5, 255.5, 255.5, -0.5)

# %%
# Showing the confusion matrix and accuracy metrics for the training data

true_labels = np.reshape(y_train, (y_train.shape[0]* y_train.shape[1]*y_train.shape[2]))
predicted_labels = np.reshape(pred_train, (pred_train.shape[0]* pred_train.shape[1]*pred_train.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[1254374   96896   73559   58420    2150]
#  [  66923  980611   68627  438994     103]
#  [  24573   73839 1077717    7005     121]
#  [  32630  180922   17147 1691283      23]
#  [   6727    1809     760     536    4635]]
#
# Metrics
# =======
# Accuracy:  81.30369795129654
# F1score:  [87.39376011 67.87797192 89.02834083 82.13614398 43.11828457]
# Recall:  [84.44693985 63.05133939 91.08070534 87.99576484 32.03843229]
# Precision:  [90.55367821 73.50482768 87.06643184 77.00818399 65.91296928]

# %%
# Showing the confusion matrix and accuracy metrics for the validation data

true_labels = np.reshape(y_valid, (y_valid.shape[0]* y_valid.shape[1]*y_valid.shape[2]))
predicted_labels = np.reshape(pred_valid, (pred_valid.shape[0]* pred_valid.shape[1]*pred_valid.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
# Out:
# Confusion  matrix
# =================
# [[235924  29820  27122  17313    451]
#  [  6415 235603  29683 107423    162]
#  [  9381  21510 269021   1079     58]
#  [  5859  46969   2511 455834      1]
#  [  2035    673    434     32   2015]]
#
# Metrics
# =======
# Accuracy:  79.5047262440557
# F1score:  [82.74493024 66.00808841 85.42790003 83.42076488 51.16810564]
# Recall:  [75.95016579 62.117505   89.36120034 89.17394077 38.83214492]
# Precision:  [90.8749143  70.41859075 81.82625597 78.36494573 74.99069594]

# %%
# Freeing up memory

x_train = 0
y_train = 0
x_valid = 0
y_valid = 0
pred_train = 0
pred_valid = 0
true_labels = 0
predicted_labels = 0

# %% [markdown]
# # **14. Inference (testing the CNN model)**

# %%
# load the best model (.h5 file)
best_model_filename = 'best_CNN_model'
model = load_model(root_path + best_model_filename + '.h5', compile=False)

# %%
# Constants

# patch_size defines the measures (spatial dimensions) of the patch.
# Working with square patches (H = W). Therefore, a scalar variable is enough.
patch_test_size = patch_size
patch_test_stride = 128

# %%
# Extracting test patches

x_patches_test, y_patches_test = extract_patches(image_test, labels_test, patch_test_size, patch_test_stride, True)

print( "Number of patches: %d %s " % ( x_patches_test.shape[0], x_patches_test.shape[1:] ) )
print( "Number of labeled references: %d %s " % ( y_patches_test.shape[0], y_patches_test.shape[1:] ) )
# Out:
# Image dimensions: (2558, 2818, 3)
# Reference dimensions: (1507328,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-495df8e5c939> in <cell line: 3>()
#       1 # Extracting test patches
#       2
# ----> 3 x_patches_test, y_patches_test = extract_patches(image_test, labels_test, patch_test_size, patch_test_stride, True)
#       4
#       5 print( "Number of patches: %d %s " % ( x_patches_test.shape[0], x_patches_test.shape[1:] ) )
#
# <ipython-input-10-ac8585de8e2c> in extract_patches(image, reference, patch_size, stride, border_patches)
#      45             if ( (m*stride+patch_size <= image.shape[0]) and (n*stride+patch_size <= image.shape[1]) ):
#      46                 patch_img.append( image[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size,:] )
# ---> 47                 patch_ref.append( reference[m*stride:m*stride+patch_size,n*stride:n*stride+patch_size] )
#      48             elif border_patches:
#      49                 border_patch_img = np.zeros((patch_size,patch_size,image_channels))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# # **15. Prediction over test patches**

# %%
# Test the model over test patches

pred_test_patches = Test(model, x_patches_test)
print(pred_test_patches.shape)

# %%
# Showing prediction result for an arbitrary test patch

index = 20

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow(x_patches_test[index])
ax1.set_title('Patch', fontsize=20)
ax1.axis('off')

ax2.imshow( y_patches_test[index], cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_test_patches[index], cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')

# %%
# Showing the confusion matrix and accuracy metrics for the test data (patches)

true_labels = np.reshape(y_patches_test, (y_patches_test.shape[0]* y_patches_test.shape[1]*y_patches_test.shape[2]))
predicted_labels = np.reshape(pred_test_patches, (pred_test_patches.shape[0]* pred_test_patches.shape[1]*pred_test_patches.shape[2]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])

# %% [markdown]
# # **16. Mosaic of the test patches predictions**

# %%
# Assembling mosaic of the test patches predictions

pred_test_mosaic = np.zeros(labels_test.shape)
patch_test_overlap = patch_test_stride/patch_test_size

# Image positions
x = y = 0
xmax, ymax = labels_test.shape

# Patch positions
pi = patch_test_size//2 - int(patch_test_size*patch_test_overlap**2)
pf = patch_test_size//2 + int(patch_test_size*patch_test_overlap**2)

for patch in pred_test_patches:
  if y==0: ypi = 0
  else: ypi = pi
  if y+pf+patch_test_stride>ymax: ypf = ymax-y-2
  else: ypf = pf
  if x==0: xpi = 0
  else: xpi = pi
  if x+pf+patch_test_stride>xmax: xpf = xmax-x
  else: xpf = pf

  pred_test_mosaic[x+xpi:x+xpf,y+ypi:y+ypf] = patch[xpi:xpf,ypi:ypf]

  y += patch_test_stride
  if y+patch_test_stride >= ymax:
    x += patch_test_stride
    y = 0

# %%
# Showing prediction results mosaic

print('\nPlotting images...')
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(15, 15))

ax1.imshow( image_test )
ax1.set_title('Image', fontsize=20)
ax1.axis('off')

ax2.imshow( labels_test, cmap='gray', vmin=0, vmax=num_classes )
ax2.set_title('Reference', fontsize=20)
ax2.axis('off')

ax3.imshow( pred_test_mosaic, cmap='gray', vmin=0, vmax=num_classes )
ax3.set_title('Prediction', fontsize=20)
ax3.axis('off')

# %%
# Showing the confusion matrix and accuracy metrics for the prediction results mosaic

true_labels = np.reshape(labels_test, (labels_test.shape[0]*labels_test.shape[1]))
predicted_labels = np.reshape(pred_test_mosaic, (pred_test_mosaic.shape[0]*pred_test_mosaic.shape[1]))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
print('Confusion  matrix')
print('=================')
print(cm)

# Metrics
metrics = compute_metrics(true_labels, predicted_labels)
print('\nMetrics')
print('=======')
print('Accuracy: ', metrics[0])
print('F1score: ', metrics[1])
print('Recall: ', metrics[2])
print('Precision: ', metrics[3])
